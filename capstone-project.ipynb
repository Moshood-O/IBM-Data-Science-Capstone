# %% [markdown]
# <h1 align="center"><font size="5">LOCATION RECOMMENDER SYSTEM FOR A TOURISM-BASED HOTEL</font></h1>
# <h1 align="center"><font size="5">CASE STUDY: LOS ANGELES</font></h1>

# %% [markdown]
# In this notebook, the best locations for situating a hotel in los angeles are recommended based on the kinds of venues that are in their proximity. The list of neighborhoods are scraped from a wikipedia page and their coordinates are generated using the geopy library and manual entry. The neighborhoods are explored by leveraging foursquare location data

# %% [markdown]
# ## Table of contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ol>
#         <li><a href="#ref1">Data Acquisition and Cleaning</a></li>
#         <li><a href="#ref2">Explore the Neighborhoods</a></li>
#         <li><a href="#ref3">Designing the Recommender System</a></li>
#     </ol>
# </div>
# <br>

# %% [markdown]
# ### Import necessary dependencies

# %%
from bs4 import BeautifulSoup as bs # for scraping

import requests # for sending web requests

# data manipulation
import pandas as pd
from pandas import json_normalize
import numpy as np

# for obtaining the coordinates of a location
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# visualization tools
import folium
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline

# %% [markdown]
# ### This code is used to suppress all warnings

# %%
# %%javascript
# (function(on) {
# const e=$( "<a>Setup failed</a>" );
# const ns="js_jupyter_suppress_warnings";
# var cssrules=$("#"+ns);
# if(!cssrules.length) cssrules = $("<style id='"+ns+"' type='text/css'>div.output_stderr { } </style>").appendTo("head");
# e.click(function() {
#     var s='Showing';
#     cssrules.empty()
#     if(on) {
#         s='Hiding';
#         cssrules.append("div.output_stderr, div[data-mime-type*='.stderr'] { display:none; }");
#     }
#     e.text(s+' warnings (click to toggle)');
#     on=!on;
# }).click();
# $(element).append(e);
# })(true);

# %% [markdown]
# <a id="ref1"></a>
# # 1. Data Acquisition and Cleaning

# %% [markdown]
# **Send a GET request to the URL of the wikipedia page containing the data**

# %%
url = "https://en.wikipedia.org/wiki/List_of_districts_and_neighborhoods_of_Los_Angeles"
html_content = requests.get(url).text

# %% [markdown]
# **Fetch and parse the data using BeautifulSoup**

# %%
soup = bs(html_content, "html5lib")

# %% [markdown]
# **Retrieve data**

# %%
raw_data = soup.find_all("div", attrs={"class": "div-col"})

# %% [markdown]
# **Clean the raw data and store it in a list**

# %%
neighborhoods = []
for data in raw_data:
    for li in data.ul.find_all("li"):
        neighborhoods.append(li.text.split("[")[0].strip())

# %% [markdown]
# How many neighborhoods were retrieved?

# %%
len(neighborhoods)
# Out:
# 199

# %% [markdown]
# View the first five neighborhoods

# %%
neighborhoods[:5]
# Out:
# ['Angelino Heights',
#  'Angeles Mesa',
#  'Angelus Vista',
#  'Arleta',
#  'Arlington Heights']

# %% [markdown]
# **Create a dataframe containing the neighborhoods retrieved**

# %%
neighborhoods_df = pd.DataFrame(neighborhoods, columns=["Neighborhood"])
neighborhoods_df.head()
# Out:
#         Neighborhood
# 0   Angelino Heights
# 1       Angeles Mesa
# 2      Angelus Vista
# 3             Arleta
# 4  Arlington Heights

# %% [markdown]
# Rename neighborhood for simplicity

# %%
neighborhoods_df["Neighborhood"].replace(to_replace=["Bel Air, Bel-Air or Bel Air Estates"], value=["Bel Air"],\
                                        inplace=True)

# %% [markdown]
# Warehouse District and Wholesale District are the same neighborhood so delete one of them

# %%
index = neighborhoods_df[neighborhoods_df["Neighborhood"] == "Wholesale District"].index
neighborhoods_df.drop(index=index, inplace=True)
neighborhoods_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# **Obtain the coordinates (latitudes and longitudes) of the neighborhoods**

# %%
locator = Nominatim(user_agent="myGeocoder")

geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

address = neighborhoods_df["Neighborhood"].apply(lambda x: x + ", Los Angeles, USA")
location = address.apply(geocode)

coordinates = location.apply(lambda loc: tuple(loc.point) if loc else None)

neighborhoods_df[['Latitude', 'Longitude', 'Altitude']] = pd.DataFrame(
    coordinates.tolist(), index=neighborhoods_df.index)

neighborhoods_df.drop(["Altitude"], axis=1, inplace=True)

neighborhoods_df.head()
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Lincoln Heights, Los Angeles, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1319, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1252, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1298, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1247, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 966, in send
#     self.connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1414, in connect
#     super().connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 938, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 728, in create_connection
#     raise err
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1362, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1321, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 408, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 394, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Lincoln Heights, Los Angeles, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1319, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1252, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1298, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1247, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 966, in send
#     self.connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1414, in connect
#     super().connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 938, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 728, in create_connection
#     raise err
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1362, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1321, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 408, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 394, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Little Tokyo, Los Angeles, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1319, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1252, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1298, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1247, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 966, in send
#     self.connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1414, in connect
#     super().connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 938, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 728, in create_connection
#     raise err
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1362, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1321, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 408, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 394, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Rose Hills, Los Angeles, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1362, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1322, in do_open
#     r = h.getresponse()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 408, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 398, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Rose Hills, Los Angeles, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1319, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1252, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1298, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1247, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 966, in send
#     self.connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1414, in connect
#     super().connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 938, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 728, in create_connection
#     raise err
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1362, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1321, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 408, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 394, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter swallowed an error after 2 retries. Called with (*('Rose Hills, Los Angeles, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1362, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1322, in do_open
#     r = h.getresponse()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 408, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 398, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Rustic Canyon, Los Angeles, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1319, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1252, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1298, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1247, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 966, in send
#     self.connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1414, in connect
#     super().connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 938, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 728, in create_connection
#     raise err
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1362, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1321, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 408, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 394, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Skid Row, Los Angeles, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1362, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1322, in do_open
#     r = h.getresponse()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 408, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 398, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('South Central, Historic, Los Angeles, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1319, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1252, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1298, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1247, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 966, in send
#     self.connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1422, in connect
#     server_hostname=server_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 423, in wrap_socket
#     session=session
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 870, in _create
#     self.do_handshake()
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# socket.timeout: _ssl.c:1059: The handshake operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1362, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1321, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error _ssl.c:1059: The handshake operation timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 408, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 394, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('South Central, Historic, Los Angeles, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1319, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1252, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1298, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1247, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 966, in send
#     self.connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1414, in connect
#     super().connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 938, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 728, in create_connection
#     raise err
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1362, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1321, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 408, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 394, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter swallowed an error after 2 retries. Called with (*('South Central, Historic, Los Angeles, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1319, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1252, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1298, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1247, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 966, in send
#     self.connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1414, in connect
#     super().connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 938, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 728, in create_connection
#     raise err
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1362, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1321, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 408, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 394, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Spaulding Square, Los Angeles, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1319, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1252, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1298, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1247, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 966, in send
#     self.connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1414, in connect
#     super().connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 938, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 728, in create_connection
#     raise err
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1362, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1321, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 408, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 394, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Spaulding Square, Los Angeles, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1319, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1252, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1298, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1247, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 966, in send
#     self.connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1414, in connect
#     super().connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 938, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 728, in create_connection
#     raise err
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1362, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1321, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 408, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 394, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Thai Town, Los Angeles, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1362, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1322, in do_open
#     r = h.getresponse()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1344, in getresponse
#     response.begin()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\user-pc\anaconda3\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 408, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 398, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('University Hills, Los Angeles, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1319, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1252, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1298, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1247, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 966, in send
#     self.connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1422, in connect
#     server_hostname=server_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 423, in wrap_socket
#     session=session
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 870, in _create
#     self.do_handshake()
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# socket.timeout: _ssl.c:1059: The handshake operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1362, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1321, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error _ssl.c:1059: The handshake operation timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 408, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 394, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Windsor Square, Los Angeles, USA',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1319, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1252, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1298, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1247, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 966, in send
#     self.connect()
#   File "C:\Users\user-pc\anaconda3\lib\http\client.py", line 1422, in connect
#     server_hostname=server_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 423, in wrap_socket
#     session=session
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 870, in _create
#     self.do_handshake()
#   File "C:\Users\user-pc\anaconda3\lib\ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# socket.timeout: _ssl.c:1059: The handshake operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1362, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\user-pc\anaconda3\lib\urllib\request.py", line 1321, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error _ssl.c:1059: The handshake operation timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 408, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\user-pc\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 394, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
#         Neighborhood   Latitude   Longitude
# 0   Angelino Heights  34.070289 -118.254796
# 1       Angeles Mesa  33.991402 -118.319520
# 2      Angelus Vista        NaN         NaN
# 3             Arleta  34.241327 -118.432205
# 4  Arlington Heights  34.043494 -118.321374

# %% [markdown]
# **Replace nan values with 0**

# %%
neighborhoods_df.fillna(0, inplace=True)
neighborhoods_df.head()
# Out:
#         Neighborhood   Latitude   Longitude
# 0   Angelino Heights  34.070289 -118.254796
# 1       Angeles Mesa  33.991402 -118.319520
# 2      Angelus Vista   0.000000    0.000000
# 3             Arleta  34.241327 -118.432205
# 4  Arlington Heights  34.043494 -118.321374

# %% [markdown]
# **The coordinates of some locations were not returned so the data will be manually sourced and saved in a csv file**

# %% [markdown]
# **First, let's get a dataframe of the neighborhoods with missing coordinates**

# %%
missing = neighborhoods_df[(neighborhoods_df.Latitude == 0) & (neighborhoods_df.Longitude == 0)]
missing.head()
# Out:
#          Neighborhood  Latitude  Longitude
# 2       Angelus Vista       0.0        0.0
# 10      Baldwin Vista       0.0        0.0
# 23     Brentwood Glen       0.0        0.0
# 31     Castle Heights       0.0        0.0
# 46  East Gate Bel Air       0.0        0.0

# %% [markdown]
# Save the **missing** dataframe to a csv file

# %%
missing.to_csv("Missing.csv")

# %% [markdown]
# **Having manually populated the csv file with the mising coordinates, the file is now read into a dataframe**

# %%
missing = pd.read_csv("Missing_fill.csv", index_col=0)
missing.head()
# Out:
#          Neighborhood   Latitude   Longitude
# 2       Angelus Vista  34.046954 -118.317488
# 10      Baldwin Vista  34.013500 -118.362700
# 23     Brentwood Glen  34.065500 -118.462700
# 31     Castle Heights  34.031400 -118.399900
# 46  East Gate Bel Air  34.080833 -118.435556

# %% [markdown]
# **Get a dataframe of the neighborhoods whose coordinates were returned by the geopy library**

# %%
available = neighborhoods_df[(neighborhoods_df.Latitude != 0) & (neighborhoods_df.Longitude != 0)]
available.head()
# Out:
#         Neighborhood   Latitude   Longitude
# 0   Angelino Heights  34.070289 -118.254796
# 1       Angeles Mesa  33.991402 -118.319520
# 3             Arleta  34.241327 -118.432205
# 4  Arlington Heights  34.043494 -118.321374
# 5      Arts District  34.041239 -118.234450

# %% [markdown]
# **Merge the available and missing dataframes into one**

# %%
neighborhoods = pd.concat([available, missing], axis=0)

#Sort dataframe alphabetically
neighborhoods = neighborhoods.reset_index().sort_values(by="index").reset_index(drop=True).drop("index", axis=1)

# round all coordinate values to 4 d.p
neighborhoods.iloc[:, 1:] = neighborhoods.iloc[:, 1:].apply(lambda x: round(x, 4))

neighborhoods.head()
# Out:
#         Neighborhood  Latitude  Longitude
# 0   Angelino Heights   34.0703  -118.2548
# 1       Angeles Mesa   33.9914  -118.3195
# 2      Angelus Vista   34.0470  -118.3175
# 3             Arleta   34.2413  -118.4322
# 4  Arlington Heights   34.0435  -118.3214

# %% [markdown]
# **Check dataframe for duplicates**

# %%
neighborhoods[neighborhoods.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Neighborhood, Latitude, Longitude]
# Index: []

# %% [markdown]
# There are no duplicates

# %% [markdown]
# ### Save it to a csv file for future references

# %%
neighborhoods.to_csv("LA_geospatial_data.csv")

# %% [markdown]
# ### Now that we have a complete dataframe, let's visualize the nieghborhoods on a map centering around LA

# %% [markdown]
# **Obtain the coordinates of los angeles**

# %%
address = "Los Angeles, USA"
locator = Nominatim(user_agent="foursquare_agent")
location = locator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %% [markdown]
# **Create and show map of LA highlighting its neighborhoods**

# %%
la_map = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, label in zip(neighborhoods["Latitude"], neighborhoods["Longitude"], neighborhoods["Neighborhood"]):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(la_map)  
la_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <a id="ref2"></a>
# # 2. Explore the Neighborhoods

# %% [markdown]
# **Define Foursquare Credentials and Version**

# %%
CLIENT_ID = "MHJUWL4WN3DUWTZZZUVXB4EELKI4315Z4QS4ZCKZK4YN2A30" # Foursquare ID
CLIENT_SECRET = "T4Q0QYJJYZJFL2LTGPTLG33LB43QNYHVLBTS42SZEXE4LXHW" # Foursquare Secret
VERSION = "20180605" # Foursquare API version

print("Your credentials:")
print("CLIENT_ID: " + CLIENT_ID)
print("CLIENT_SECRET:" + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: MHJUWL4WN3DUWTZZZUVXB4EELKI4315Z4QS4ZCKZK4YN2A30
# CLIENT_SECRET:T4Q0QYJJYZJFL2LTGPTLG33LB43QNYHVLBTS42SZEXE4LXHW

# %% [markdown]
# ### Let's explore one of the neighborhoods

# %% [markdown]
# **Get the neighborhood's name and coordinates**

# %%
neighborhood_latitude = neighborhoods.loc[0, "Latitude"] # neighborhood latitude value
neighborhood_longitude = neighborhoods.loc[0, "Longitude"] # neighborhood longitude value

neighborhood_name = neighborhoods.loc[0, "Neighborhood"] # neighborhood name

print(f"Latitude and longitude values of {neighborhood_name} are {neighborhood_latitude}, {neighborhood_longitude}")
# Out:
# Latitude and longitude values of Angelino Heights are 34.0703, -118.2548

# %% [markdown]
# ### Let's get the top 100 venues within a 1000 m radius of the neighborhood

# %% [markdown]
# **Make an explore call to Foursquare API and get the results**

# %%
LIMIT = 200
RADIUS = 1000

url = f"https://api.foursquare.com/v2/venues/explore?client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}\
&ll={neighborhood_latitude}, {neighborhood_longitude}&v={VERSION}&radius={RADIUS}&limit={LIMIT}"

results = requests.get(url).json()

# %% [markdown]
# **View the results**

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ef6da8cf1ed7d287630a183'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': '$-$$$$', 'key': 'price'},
#     {'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'East LA',
#   'headerFullLocation': 'East LA, Los Angeles',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 94,
#   'suggestedBounds': {'ne': {'lat': 34.079300009000015,
#     'lng': -118.24395531373428},
#    'sw': {'lat': 34.06129999099999, 'lng': -118.26564468626573}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f75a626e5e8f16c87566797',
#        'name': 'Halliwell Manor',
#        'location': {'address': '1329 Carroll Ave',
#         'lat': 34.069328534140894,
#         'lng': -118.25416524263122,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.069328534140894,
#           'lng': -118.25416524263122},
#          {'label': 'entrance', 'lat': 34.069447, 'lng': -118.254056}],
#         'distance': 122,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1329 Carroll Ave',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f2931735',
#          'name': 'Performing Arts Venue',
#          'pluralName': 'Performing Arts Venues',
#          'shortName': 'Performing Arts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f75a626e5e8f16c87566797-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50e4af3de4b067b02e8b8842',
#        'name': 'Guisados',
#        'location': {'address': '1261 W Sunset Blvd',
#         'lat': 34.07026183469215,
#         'lng': -118.25043738234746,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07026183469215,
#           'lng': -118.25043738234746}],
#         'distance': 402,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1261 W Sunset Blvd',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d151941735',
#          'name': 'Taco Place',
#          'pluralName': 'Taco Places',
#          'shortName': 'Tacos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1198296',
#         'url': 'https://www.grubhub.com/restaurant/guisados-1261-w-sunset-blvd-los-angeles/1198296?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1198296',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50e4af3de4b067b02e8b8842-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '560da0fe498e6ed2d672b8ce',
#        'name': 'Eightfold Coffee',
#        'location': {'address': '1294 W Sunset Blvd',
#         'lat': 34.071244903595876,
#         'lng': -118.25069827337198,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.071244903595876,
#           'lng': -118.25069827337198},
#          {'label': 'entrance', 'lat': 34.071198, 'lng': -118.250729}],
#         'distance': 392,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1294 W Sunset Blvd',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '352348522'}},
#       'referralId': 'e-0-560da0fe498e6ed2d672b8ce-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c24e96775dcb7002cf25653',
#        'name': 'Ototo',
#        'location': {'address': '1360 Allison Ave',
#         'lat': 34.07265853881836,
#         'lng': -118.25173950195312,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07265853881836,
#           'lng': -118.25173950195312}],
#         'distance': 385,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1360 Allison Ave',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11c941735',
#          'name': 'Sake Bar',
#          'pluralName': 'Sake Bars',
#          'shortName': 'Sake Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sake_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c24e96775dcb7002cf25653-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be5e017bcef2d7f807704e5',
#        'name': 'Subliminal Projects',
#        'location': {'address': '1331 W Sunset Blvd',
#         'crossStreet': 'at Elysian Park Ave',
#         'lat': 34.07229015197213,
#         'lng': -118.25073731121631,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07229015197213,
#           'lng': -118.25073731121631},
#          {'label': 'entrance', 'lat': 34.072278, 'lng': -118.250658}],
#         'distance': 435,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1331 W Sunset Blvd (at Elysian Park Ave)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e2931735',
#          'name': 'Art Gallery',
#          'pluralName': 'Art Galleries',
#          'shortName': 'Art Gallery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '94496514'}},
#       'referralId': 'e-0-4be5e017bcef2d7f807704e5-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55f142eb498e4c684bb0c3ba',
#        'name': 'Button Mash',
#        'location': {'address': '1391 W Sunset Blvd',
#         'lat': 34.073974917387645,
#         'lng': -118.25150732788204,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.073974917387645,
#           'lng': -118.25150732788204},
#          {'label': 'entrance', 'lat': 34.073905, 'lng': -118.251411}],
#         'distance': 509,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1391 W Sunset Blvd',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e1931735',
#          'name': 'Arcade',
#          'pluralName': 'Arcades',
#          'shortName': 'Arcade',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/arcade_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1453198',
#         'url': 'https://www.grubhub.com/restaurant/button-mash-1391-sunset-blvd-los-angeles/1453198?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1453198',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55f142eb498e4c684bb0c3ba-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '589240b80393cc2d0c993f8a',
#        'name': 'Tsubaki',
#        'location': {'address': '1356 Allison Ave',
#         'lat': 34.07293766907906,
#         'lng': -118.25129829595535,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07293766907906,
#           'lng': -118.25129829595535},
#          {'label': 'entrance', 'lat': 34.072676, 'lng': -118.251791}],
#         'distance': 436,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1356 Allison Ave',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-589240b80393cc2d0c993f8a-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bafbdb3c9f907002c6f7dca',
#        'name': 'Konbi',
#        'location': {'address': '1463 W Sunset Blvd',
#         'lat': 34.07538259775033,
#         'lng': -118.25389270445339,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07538259775033,
#           'lng': -118.25389270445339},
#          {'label': 'entrance', 'lat': 34.07537, 'lng': -118.253779}],
#         'distance': 571,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1463 W Sunset Blvd',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bafbdb3c9f907002c6f7dca-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e45d32eb0fb93df2701eeb3',
#        'name': "The Park's Finest BBQ",
#        'location': {'address': '1267 W Temple St',
#         'crossStreet': 'at E Edgeware Rd',
#         'lat': 34.06651930066153,
#         'lng': -118.2542906745739,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.06651930066153,
#           'lng': -118.2542906745739},
#          {'label': 'entrance', 'lat': 34.066413, 'lng': -118.254147}],
#         'distance': 423,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1267 W Temple St (at E Edgeware Rd)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '95346544'}},
#       'referralId': 'e-0-4e45d32eb0fb93df2701eeb3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e72b052d22d2fd313fa72fc',
#        'name': 'Sunset Beer Company',
#        'location': {'address': '1498 W Sunset Blvd Ste 3',
#         'crossStreet': 'btw Laveta Ter & Portia St',
#         'lat': 34.07547830678042,
#         'lng': -118.25531077390929,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07547830678042,
#           'lng': -118.25531077390929}],
#         'distance': 578,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1498 W Sunset Blvd Ste 3 (btw Laveta Ter & Portia St)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '5370f356bcbc57f1066c94c2',
#          'name': 'Beer Store',
#          'pluralName': 'Beer Stores',
#          'shortName': 'Beer Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e72b052d22d2fd313fa72fc-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53df045f498e8fd8d8e3ed34',
#        'name': "Leo's Tacos",
#        'location': {'address': '\u200b415 Glendale Blvd',
#         'lat': 34.06774324019533,
#         'lng': -118.2609739674246,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.06774324019533,
#           'lng': -118.2609739674246}],
#         'distance': 636,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['\u200b415 Glendale Blvd',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d151941735',
#          'name': 'Taco Place',
#          'pluralName': 'Taco Places',
#          'shortName': 'Tacos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53df045f498e8fd8d8e3ed34-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54a7698a498e98a2023c0a00',
#        'name': 'Ostrich Farm',
#        'location': {'address': '1525 W Sunset Blvd',
#         'lat': 34.07627157279621,
#         'lng': -118.25591940752977,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07627157279621,
#           'lng': -118.25591940752977}],
#         'distance': 672,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1525 W Sunset Blvd',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54a7698a498e98a2023c0a00-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b64a54df964a5203ac52ae3',
#        'name': 'K Bakery',
#        'location': {'address': '1258 W Temple St',
#         'crossStreet': 'btw Edgeware & Bixel',
#         'lat': 34.06612437290088,
#         'lng': -118.25405857193756,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.06612437290088,
#           'lng': -118.25405857193756},
#          {'label': 'entrance', 'lat': 34.066052, 'lng': -118.254146}],
#         'distance': 469,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1258 W Temple St (btw Edgeware & Bixel)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b64a54df964a5203ac52ae3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49c1c9a0f964a520cd551fe3',
#        'name': 'The Park Restaurant',
#        'location': {'address': '1400 W Sunset Blvd',
#         'crossStreet': 'at Douglas St',
#         'lat': 34.07424337502603,
#         'lng': -118.2522421389902,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07424337502603,
#           'lng': -118.2522421389902},
#          {'label': 'entrance', 'lat': 34.074283, 'lng': -118.252274}],
#         'distance': 498,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1400 W Sunset Blvd (at Douglas St)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-49c1c9a0f964a520cd551fe3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aa16165f964a520764020e3',
#        'name': 'Pho Siam Thai Spa',
#        'location': {'address': '1525 Pizarro St',
#         'lat': 34.06688510749023,
#         'lng': -118.26096799120259,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.06688510749023,
#           'lng': -118.26096799120259},
#          {'label': 'entrance', 'lat': 34.066837, 'lng': -118.261131}],
#         'distance': 684,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1525 Pizarro St',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#          'name': 'Massage Studio',
#          'pluralName': 'Massage Studios',
#          'shortName': 'Massage Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aa16165f964a520764020e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bc1a4b435811b002c0450c3',
#        'name': 'Bar Henry',
#        'location': {'address': '1228 W Sunset Blvd',
#         'lat': 34.06906170506543,
#         'lng': -118.2504651324914,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.06906170506543,
#           'lng': -118.2504651324914}],
#         'distance': 422,
#         'postalCode': '90026',
#         'cc': 'US',
#         'neighborhood': 'Greater Echo Park Elysian',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1228 W Sunset Blvd',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bc1a4b435811b002c0450c3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a89f435fc9e9457d635bc23',
#        'name': 'Hey Hey',
#        'location': {'address': '1555 W Sunset Blvd',
#         'lat': 34.07662241627549,
#         'lng': -118.2566763319372,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07662241627549,
#           'lng': -118.2566763319372}],
#         'distance': 724,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1555 W Sunset Blvd',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a89f435fc9e9457d635bc23-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb8f5d6c7228cfaba9d0cce',
#        'name': 'Blue Corn Quesadilla Lady',
#        'location': {'lat': 34.07627046112305,
#         'lng': -118.25782151503442,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07627046112305,
#           'lng': -118.25782151503442}],
#         'distance': 720,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['Los Angeles, CA 90026', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1be941735',
#          'name': 'Latin American Restaurant',
#          'pluralName': 'Latin American Restaurants',
#          'shortName': 'Latin American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb8f5d6c7228cfaba9d0cce-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '541db696498e5208eda9f5f5',
#        'name': 'Woodcat',
#        'location': {'address': '1532 W Sunset Blvd',
#         'crossStreet': 'Laveta Terrace',
#         'lat': 34.07621992817524,
#         'lng': -118.25632133250227,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07621992817524,
#           'lng': -118.25632133250227}],
#         'distance': 673,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1532 W Sunset Blvd (Laveta Terrace)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1528523',
#         'url': 'https://www.grubhub.com/restaurant/woodcat-coffee-bar-1532-sunset-boulevard-los-angeles/1528523?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1528523',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-541db696498e5208eda9f5f5-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba5a6bff964a5207e1939e3',
#        'name': '1642 Beer And Wine',
#        'location': {'address': '1642 W Temple St',
#         'lat': 34.06842824086621,
#         'lng': -118.26237860192134,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.06842824086621,
#           'lng': -118.26237860192134},
#          {'label': 'entrance', 'lat': 34.068324, 'lng': -118.262335}],
#         'distance': 729,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1642 W Temple St',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba5a6bff964a5207e1939e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9e3a0491cb236a18166397',
#        'name': 'Michael Jackson\'s "Thriller" House (and Tree)',
#        'location': {'address': '1345 Carroll Ave',
#         'lat': 34.069557379373215,
#         'lng': -118.25459920048158,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.069557379373215,
#           'lng': -118.25459920048158},
#          {'label': 'entrance', 'lat': 34.069654, 'lng': -118.254528}],
#         'distance': 84,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1345 Carroll Ave',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d9e3a0491cb236a18166397-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52a20aa611d219d85ea70a7d',
#        'name': 'Trencher',
#        'location': {'address': '1305 Portia St',
#         'crossStreet': 'at Sunset Blvd',
#         'lat': 34.07576919078519,
#         'lng': -118.25429735272242,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07576919078519,
#           'lng': -118.25429735272242}],
#         'distance': 610,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1305 Portia St (at Sunset Blvd)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1527387',
#         'url': 'https://www.grubhub.com/restaurant/trencher-1305-portia-street-los-angeles/1527387?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1527387',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '129953083'}},
#       'referralId': 'e-0-52a20aa611d219d85ea70a7d-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d7060ae68276ea855578790',
#        'name': 'Sage Organic Vegan Bistro',
#        'location': {'address': '1700 W Sunset Blvd',
#         'crossStreet': 'at Logan St',
#         'lat': 34.07715025130554,
#         'lng': -118.25850979016774,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07715025130554,
#           'lng': -118.25850979016774}],
#         'distance': 835,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1700 W Sunset Blvd (at Logan St)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '348824',
#         'url': 'https://www.grubhub.com/restaurant/sage-vegan-bistro-1700-w-sunset-blvd-los-angeles/348824?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=348824',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d7060ae68276ea855578790-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49ea9e60f964a52084661fe3',
#        'name': 'Stories Books & Cafe',
#        'location': {'address': '1716 W Sunset Blvd',
#         'crossStreet': 'at Logan St',
#         'lat': 34.07723989349747,
#         'lng': -118.25918588264082,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07723989349747,
#           'lng': -118.25918588264082},
#          {'label': 'entrance', 'lat': 34.077347, 'lng': -118.259057}],
#         'distance': 871,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1716 W Sunset Blvd (at Logan St)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-49ea9e60f964a52084661fe3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d4e746d61835c0008428269',
#        'name': 'Bar Flores',
#        'location': {'address': '1542 Sunset Blvd',
#         'crossStreet': 'Echo Park Ave',
#         'lat': 34.076206,
#         'lng': -118.256515,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.076206,
#           'lng': -118.256515}],
#         'distance': 676,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1542 Sunset Blvd (Echo Park Ave)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5d4e746d61835c0008428269-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a7ac2c3f964a52077e91fe3',
#        'name': 'Tacos Arizas',
#        'location': {'address': '1160 Logan St',
#         'crossStreet': 'at W Sunset Blvd',
#         'lat': 34.07730111851808,
#         'lng': -118.2581584145646,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07730111851808,
#           'lng': -118.2581584145646}],
#         'distance': 838,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1160 Logan St (at W Sunset Blvd)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a7ac2c3f964a52077e91fe3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '3fd66200f964a52002ef1ee3',
#        'name': 'The Short Stop',
#        'location': {'address': '1455 W Sunset Blvd',
#         'crossStreet': 'at Sutherland St',
#         'lat': 34.075293396715004,
#         'lng': -118.25370059636991,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.075293396715004,
#           'lng': -118.25370059636991}],
#         'distance': 565,
#         'postalCode': '90026',
#         'cc': 'US',
#         'neighborhood': 'Echo Park',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1455 W Sunset Blvd (at Sutherland St)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '91901867'}},
#       'referralId': 'e-0-3fd66200f964a52002ef1ee3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c11ef6017002d7f2d11e709',
#        'name': 'Club Bahia',
#        'location': {'address': '1130 W Sunset Blvd',
#         'lat': 34.066239927184604,
#         'lng': -118.24966913779075,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.066239927184604,
#           'lng': -118.24966913779075},
#          {'label': 'entrance', 'lat': 34.066245, 'lng': -118.249743}],
#         'distance': 654,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1130 W Sunset Blvd',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11f941735',
#          'name': 'Nightclub',
#          'pluralName': 'Nightclubs',
#          'shortName': 'Nightclub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c11ef6017002d7f2d11e709-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b787c49f964a5209bd12ee3',
#        'name': 'Vista Hermosa Park',
#        'location': {'address': '100 N Toluca St',
#         'crossStreet': '1st St',
#         'lat': 34.06160137469902,
#         'lng': -118.25685739517212,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.06160137469902,
#           'lng': -118.25685739517212},
#          {'label': 'entrance', 'lat': 34.061956, 'lng': -118.257981}],
#         'distance': 986,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['100 N Toluca St (1st St)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b787c49f964a5209bd12ee3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57fe8d36498e909b1097c2f8',
#        'name': 'honey hi',
#        'location': {'address': '1620 W Sunset Blvd',
#         'lat': 34.07696544110822,
#         'lng': -118.25812025820687,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07696544110822,
#           'lng': -118.25812025820687}],
#         'distance': 802,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1620 W Sunset Blvd',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1528180',
#         'url': 'https://www.grubhub.com/restaurant/honey-hi-1620-sunset-boulevard-los-angeles/1528180?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1528180',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57fe8d36498e909b1097c2f8-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b173d75f964a5201bc423e3',
#        'name': 'Echo Park Deep Pool',
#        'location': {'address': '1419 Colton St',
#         'crossStreet': 'Glendale',
#         'lat': 34.06422993419488,
#         'lng': -118.25900884498822,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.06422993419488,
#           'lng': -118.25900884498822}],
#         'distance': 779,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1419 Colton St (Glendale)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d15e941735',
#          'name': 'Pool',
#          'pluralName': 'Pools',
#          'shortName': 'Pool',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b173d75f964a5201bc423e3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c16b7ca955976b07f00a5f6',
#        'name': 'Tamales Alberto',
#        'location': {'address': '1644 W Temple St',
#         'crossStreet': 'Belmont Ave',
#         'lat': 34.068220000000004,
#         'lng': -118.262547,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.068220000000004,
#           'lng': -118.262547},
#          {'label': 'entrance', 'lat': 34.06835, 'lng': -118.262469}],
#         'distance': 750,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1644 W Temple St (Belmont Ave)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1165508',
#         'url': 'https://www.grubhub.com/restaurant/tamales-alberto-westlake-1644-w-temple-st-los-angeles/1165508?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1165508',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '87882172'}},
#       'referralId': 'e-0-4c16b7ca955976b07f00a5f6-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49c885aaf964a5201e581fe3',
#        'name': 'Masa of Echo Park Bakery & Cafe',
#        'location': {'address': '1800 W Sunset Blvd',
#         'crossStreet': 'at Lemoyne St',
#         'lat': 34.07764427896131,
#         'lng': -118.25951009447397,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07764427896131,
#           'lng': -118.25951009447397},
#          {'label': 'entrance', 'lat': 34.077584, 'lng': -118.259558}],
#         'distance': 925,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1800 W Sunset Blvd (at Lemoyne St)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '159158275'}},
#       'referralId': 'e-0-49c885aaf964a5201e581fe3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '44df5606f964a520e9361fe3',
#        'name': 'The Echo',
#        'location': {'address': '1822 W Sunset Blvd',
#         'crossStreet': 'at Lemoyne St',
#         'lat': 34.077716058931244,
#         'lng': -118.26006982628856,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.077716058931244,
#           'lng': -118.26006982628856}],
#         'distance': 957,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1822 W Sunset Blvd (at Lemoyne St)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e5931735',
#          'name': 'Music Venue',
#          'pluralName': 'Music Venues',
#          'shortName': 'Music Venue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-44df5606f964a520e9361fe3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49e36797f964a5207a621fe3',
#        'name': 'Eastside Market Italian Deli',
#        'location': {'address': '1013 Alpine St',
#         'crossStreet': 'at Figueroa Ter.',
#         'lat': 34.06509874770175,
#         'lng': -118.24663350437224,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.06509874770175,
#           'lng': -118.24663350437224},
#          {'label': 'entrance', 'lat': 34.065145, 'lng': -118.246646}],
#         'distance': 949,
#         'postalCode': '90012',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1013 Alpine St (at Figueroa Ter.)',
#          'Los Angeles, CA 90012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '320537',
#         'url': 'https://www.grubhub.com/restaurant/eastside-market-italian-deli-1013-alpine-st-los-angeles/320537?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=320537',
#         'provider': {'name': 'grubhub',
# ...
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1522 W Sunset Blvd (at Laveta Terr.)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d148941735',
#          'name': 'Donut Shop',
#          'pluralName': 'Donut Shops',
#          'shortName': 'Donuts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '559816',
#         'url': 'https://www.grubhub.com/restaurant/angelinos-bakery--deli-1522-sunset-blvd-los-angeles/559816?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=559816',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '529728218'}},
#       'referralId': 'e-0-4ada0fc9f964a520eb1d21e3-81'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57378d11498e9451c0d69664',
#        'name': 'kaleidoscope kollective',
#        'location': {'address': '1511 W Sunset Blvd',
#         'crossStreet': 'Laveta',
#         'lat': 34.07622528076172,
#         'lng': -118.25545501708984,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07622528076172,
#           'lng': -118.25545501708984}],
#         'distance': 662,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1511 W Sunset Blvd (Laveta)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d128951735',
#          'name': 'Gift Shop',
#          'pluralName': 'Gift Shops',
#          'shortName': 'Gift Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57378d11498e9451c0d69664-82'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c70a08ed97fa143b2e5f6ca',
#        'name': 'The Bixel House',
#        'location': {'address': '321 N Bixel St',
#         'lat': 34.064247131347656,
#         'lng': -118.25527954101562,
#         'labeledLatLngs': [{'label': 'entrance',
#           'lat': 34.064199,
#           'lng': -118.255171},
#          {'label': 'display',
#           'lat': 34.064247131347656,
#           'lng': -118.25527954101562}],
#         'distance': 675,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['321 N Bixel St',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d167941735',
#          'name': 'Skate Park',
#          'pluralName': 'Skate Parks',
#          'shortName': 'Skate Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/skate_park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c70a08ed97fa143b2e5f6ca-83'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e751bc6483b0cf5ec9ba4a5',
#        'name': 'Villainy General Store',
#        'location': {'address': '1519 W Sunset Blvd',
#         'crossStreet': 'at Laveta Ter',
#         'lat': 34.07633972167969,
#         'lng': -118.25575256347656,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07633972167969,
#           'lng': -118.25575256347656}],
#         'distance': 678,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1519 W Sunset Blvd (at Laveta Ter)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d104951735',
#          'name': 'Boutique',
#          'pluralName': 'Boutiques',
#          'shortName': 'Boutique',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '54105783'}},
#       'referralId': 'e-0-4e751bc6483b0cf5ec9ba4a5-84'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d5f520e9bf6330007c1c43e',
#        'name': 'Monty’s Good Burger',
#        'location': {'address': '1533 W Sunset Blvd',
#         'lat': 34.076408,
#         'lng': -118.25594199999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.076408,
#           'lng': -118.25594199999999},
#          {'label': 'entrance', 'lat': 34.076345, 'lng': -118.256027}],
#         'distance': 688,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1533 W Sunset Blvd',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5d5f520e9bf6330007c1c43e-85'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e45b92a45dd2955e58e4c19',
#        'name': 'Sunset Snack Diner',
#        'location': {'address': '1608 W Sunset Blvd',
#         'crossStreet': 'btwn Logan St & Echo Park Ave',
#         'lat': 34.07665,
#         'lng': -118.25781599999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07665,
#           'lng': -118.25781599999999},
#          {'label': 'entrance', 'lat': 34.076782, 'lng': -118.257755}],
#         'distance': 759,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1608 W Sunset Blvd (btwn Logan St & Echo Park Ave)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e45b92a45dd2955e58e4c19-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf84e6892d19521d9355a1f',
#        'name': 'Little Caesars Pizza',
#        'location': {'address': '1321 Echo Park Avenue Echo Park Shopping Center',
#         'crossStreet': 'Btwn Sunset & Montana',
#         'lat': 34.0775378484286,
#         'lng': -118.25719852496542,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.0775378484286,
#           'lng': -118.25719852496542}],
#         'distance': 835,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1321 Echo Park Avenue Echo Park Shopping Center (Btwn Sunset & Montana)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf84e6892d19521d9355a1f-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56146ef7498e3d01a9a7972d',
#        'name': "Lassen's Natural Foods & Vitamins",
#        'location': {'address': '1631 W Sunset Blvd',
#         'lat': 34.07733154296875,
#         'lng': -118.25814819335938,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07733154296875,
#           'lng': -118.25814819335938}],
#         'distance': 841,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1631 W Sunset Blvd',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '54541900498ea6ccd0202697',
#          'name': 'Health & Beauty Service',
#          'pluralName': 'Health & Beauty Services',
#          'shortName': 'Health & Beauty',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56146ef7498e3d01a9a7972d-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbce1a1f57ba5930b60adb9',
#        'name': 'Pescado Mojado',
#        'location': {'address': '1701 W Sunset Blvd',
#         'crossStreet': 'Logan',
#         'lat': 34.07755,
#         'lng': -118.258412,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07755,
#           'lng': -118.258412}],
#         'distance': 873,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1701 W Sunset Blvd (Logan)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbce1a1f57ba5930b60adb9-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c9949ebfd16bb002c010e1b',
#        'name': 'Shoe Palace',
#        'location': {'address': '1724 W. SUNSET BLVD',
#         'lat': 34.07729739,
#         'lng': -118.25941639,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.07729739,
#           'lng': -118.25941639}],
#         'distance': 887,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1724 W. SUNSET BLVD',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d107951735',
#          'name': 'Shoe Store',
#          'pluralName': 'Shoe Stores',
#          'shortName': 'Shoes',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_shoestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '557626866'}},
#       'referralId': 'e-0-5c9949ebfd16bb002c010e1b-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc59a0dd4c0ad9c0f8cb2be',
#        'name': 'Rockwood/Colton Park',
#        'location': {'address': '1571 Colton St',
#         'crossStreet': 'Welcome St',
#         'lat': 34.064277,
#         'lng': -118.26199382,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.064277,
#           'lng': -118.26199382}],
#         'distance': 943,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1571 Colton St (Welcome St)',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc59a0dd4c0ad9c0f8cb2be-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c887cb3944e224b02e91c85',
#        'name': 'Dub Club',
#        'location': {'lat': 34.077623981804045,
#         'lng': -118.26017782878392,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.077623981804045,
#           'lng': -118.26017782878392}],
#         'distance': 954,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['Los Angeles, CA 90026', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11f941735',
#          'name': 'Nightclub',
#          'pluralName': 'Nightclubs',
#          'shortName': 'Nightclub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c887cb3944e224b02e91c85-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f3d9be1e4b0e4bab8f1cc50',
#        'name': 'Workshop 1495',
#        'location': {'address': '1495 Beverly Blvd, Los Angeles, CA 90026',
#         'lat': 34.06259536743164,
#         'lng': -118.2603759765625,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 34.06259536743164,
#           'lng': -118.2603759765625}],
#         'distance': 999,
#         'postalCode': '90026',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1495 Beverly Blvd, Los Angeles, CA 90026',
#          'Los Angeles, CA 90026',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e2931735',
#          'name': 'Art Gallery',
#          'pluralName': 'Art Galleries',
#          'shortName': 'Art Gallery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '36789727'}},
#       'referralId': 'e-0-4f3d9be1e4b0e4bab8f1cc50-93'}]}]}}

# %% [markdown]
# The results in the above form do not make much sense so let's clean and process it into a more understandable form

# %% [markdown]
# **Let's define a function to extract the category of each venue**

# %%
def get_category_type(row):
    try:
        categories_list = row["categories"]
    except:
        categories_list = row["venue.categories"]
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]["name"]

# %% [markdown]
# **Clean and process the json file into a dataframe**

# %%
venues = results["response"]["groups"][0]["items"]
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ["venue.name", "venue.categories", "venue.location.lat", "venue.location.lng"]
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues["venue.categories"] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

# %% [markdown]
# **View the first few rows of the resulting dataframe**

# %%
nearby_venues.head()
# Out:
#                   name             categories        lat         lng
# 0      Halliwell Manor  Performing Arts Venue  34.069329 -118.254165
# 1             Guisados             Taco Place  34.070262 -118.250437
# 2     Eightfold Coffee            Coffee Shop  34.071245 -118.250698
# 3                Ototo               Sake Bar  34.072659 -118.251740
# 4  Subliminal Projects            Art Gallery  34.072290 -118.250737

# %% [markdown]
# How many venues were returned for Angelino Heights?

# %%
nearby_venues.shape[0]
# Out:
# 94

# %% [markdown]
# ### Now, let's create and apply a function that performs the above exploration for all neighborhoods

# %%
def getNearbyVenues(names, latitudes, longitudes):
    
    RADIUS = 1000
    LIMIT = 100
    venues_list=[]
    
    for name, lat, lng in zip(names, latitudes, longitudes):
 
        # create the API request URL
        url = f"https://api.foursquare.com/v2/venues/explore?client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}\
        &ll={lat}, {lng}&v={VERSION}&radius={RADIUS}&limit={LIMIT}"
            
        # make the GET request
        results = requests.get(url).json()["response"]["groups"][0]["items"]
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v["venue"]["name"], 
            v["venue"]["location"]["lat"], 
            v["venue"]["location"]["lng"],  
            v["venue"]["categories"][0]["name"]) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ["Neighborhood", 
                  "Neighborhood Latitude", 
                  "Neighborhood Longitude", 
                  "Venue", 
                  "Venue Latitude", 
                  "Venue Longitude", 
                  "Venue Category"]
    
    return(nearby_venues)

# %%
la_venues = getNearbyVenues(neighborhoods["Neighborhood"], neighborhoods["Latitude"], neighborhoods["Longitude"])

# %% [markdown]
# **View the first few rows of the dataframe**

# %%
la_venues.head()
# Out:
#        Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Angelino Heights                34.0703               -118.2548
# 1  Angelino Heights                34.0703               -118.2548
# 2  Angelino Heights                34.0703               -118.2548
# 3  Angelino Heights                34.0703               -118.2548
# 4  Angelino Heights                34.0703               -118.2548
#
#                  Venue  Venue Latitude  Venue Longitude         Venue Category
# 0      Halliwell Manor       34.069329      -118.254165  Performing Arts Venue
# 1             Guisados       34.070262      -118.250437             Taco Place
# 2     Eightfold Coffee       34.071245      -118.250698            Coffee Shop
# 3                Ototo       34.072659      -118.251740               Sake Bar
# 4  Subliminal Projects       34.072290      -118.250737            Art Gallery

# %% [markdown]
# **Examine the shape of the dataframe**

# %%
la_venues.shape
# Out:
# (10961, 7)

# %% [markdown]
# A total of 10,961 venues were returned for all neighborhoods

# %% [markdown]
# **How many unique venue categories are there?**

# %%
la_venues["Venue Category"].value_counts()

# %%
len(la_venues["Venue Category"].unique())
# Out:
# 418

# %% [markdown]
# There are 418 unique venue categories

# %% [markdown]
# **How many venues for each neighborhood were returned?**

# %%
la_venues.groupby("Neighborhood")["Venue"].count()
# Out:
# Neighborhood
# Angeles Mesa          36
# Angelino Heights      94
# Angelus Vista         94
# Arleta                10
# Arlington Heights     42
#                     ...
# Wilshire Park         28
# Windsor Square        56
# Winnetka              29
# Woodland Hills        75
# Yucca Corridor       100
# Name: Venue, Length: 198, dtype: int64

# %% [markdown]
# **Let's check for the top 10 neighborhoods with the most venues**

# %%
la_venues.groupby("Neighborhood")["Venue"].count().sort_values(ascending=False)[:10]
# Out:
# Neighborhood
# Yucca Corridor        100
# NoHo Arts District    100
# Jewelry District      100
# Koreatown             100
# Larchmont             100
# Little Ethiopia       100
# Little Tokyo          100
# Mid-Wilshire          100
# Miracle Mile          100
# North Hollywood       100
# Name: Venue, dtype: int64

# %% [markdown]
# **What are the top 10 most common venue categories?**

# %%
la_venues.groupby("Venue Category")["Venue"].count().sort_values(ascending=False)[:10]
# Out:
# Venue Category
# Coffee Shop             507
# Mexican Restaurant      395
# Pizza Place             274
# Fast Food Restaurant    232
# Grocery Store           218
# Café                    210
# Bar                     207
# Sandwich Place          202
# Sushi Restaurant        189
# Italian Restaurant      179
# Name: Venue, dtype: int64

# %% [markdown]
# **Print the top 5 venues in each neighborhood**

# %% [markdown]
# <a id="ref3"></a>
# # 3. Designing the Recommender System

# %% [markdown]
# In choosing a location for establishing a tourism-based hotel, the most important factor is the presence of venues that attract tourists. For design purposes, the venue categories are grouped into the following broad categories and are assigned weighting factors based on their relative importance.
#
# | Category                         |  Weighting Factor  |
# |----------------------------------|--------------------|
# | Attractions/Entertainments       |        0.50        |
# | Food Services                    |        0.15        |
# | Medical Services                 |        0.15        |
# | Transportation                   |        0.20        |
#
# Attractions/Entertainments include venues such as art galleries, theme parks, theaters, golf ranges, historic sites, scenic lookouts, museums, landmarks etc. Food services include restaurants, bars, joints etc. Airports, trains, bus stations, roads etc are all classified under transportaton. Hospitals, pharmacies, drugstores, clinics are classified under medical services
#
# **Note: Venues that do not fall under any of the above categories are grouped under "Others".**

# %% [markdown]
# ## Get the general category of each venue

# %% [markdown]
# **Inspect the various venue categories to know the keywords to use to categorize them under the general categories stated above**

# %%
pd.set_option("display.max_rows", 500)
pd.DataFrame(la_venues["Venue Category"].unique())
# Out:
#                                             0
# 0                       Performing Arts Venue
# 1                                  Taco Place
# 2                                 Coffee Shop
# 3                                    Sake Bar
# 4                                 Art Gallery
# 5                                      Arcade
# 6                         Japanese Restaurant
# 7                                   BBQ Joint
# 8                                  Beer Store
# 9                         American Restaurant
# 10                                     Bakery
# 11                             Breakfast Spot
# 12                             Massage Studio
# 13                               Cocktail Bar
# 14                  Latin American Restaurant
# 15                                        Bar
# 16                              Historic Site
# 17                             Sandwich Place
# 18              Vegetarian / Vegan Restaurant
# 19                                  Bookstore
# 20                                 Food Truck
# 21                                  Nightclub
# 22                                       Park
# 23                                       Café
# 24                                       Pool
# 25                         Mexican Restaurant
# 26                                Pizza Place
# 27                                Music Venue
# 28                              Deli / Bodega
# 29                          Convenience Store
# 30                          Health Food Store
# 31                                   Wine Bar
# 32                              Hot Dog Joint
# 33                                  Rock Club
# 34                                 Comic Shop
# 35                                     Circus
# 36                                 Art Museum
# 37                           Toy / Game Store
# 38                             Farmers Market
# 39                     Thrift / Vintage Store
# 40                                 Restaurant
# 41                               Burger Joint
# 42                            Thai Restaurant
# 43                          Recreation Center
# 44                       Caribbean Restaurant
# 45                                   Pharmacy
# 46                                   Dive Bar
# 47                                Video Store
# 48                       Fast Food Restaurant
# 49                                      Motel
# 50                                      Hotel
# 51                                 Laundromat
# 52                                 Boxing Gym
# 53                              Jewelry Store
# 54                             Baseball Field
# 55                                 Donut Shop
# 56                                  Gift Shop
# 57                                 Skate Park
# 58                                   Boutique
# 59                                      Diner
# 60                    Health & Beauty Service
# 61                                 Shoe Store
# 62                             Hardware Store
# 63                                 Playground
# 64                           Video Game Store
# 65                        Fried Chicken Joint
# 66                             Discount Store
# 67                          Mobile Phone Shop
# 68                             Ice Cream Shop
# 69                         Chinese Restaurant
# 70                           Department Store
# 71                              Big Box Store
# 72                              Grocery Store
# 73                                  Pet Store
# 74                         Seafood Restaurant
# 75                                  Juice Bar
# 76                             Clothing Store
# 77                               Liquor Store
# 78                   Mediterranean Restaurant
# 79                       Marijuana Dispensary
# 80                                Yoga Studio
# 81                         Italian Restaurant
# 82                                        Spa
# 83                          Korean Restaurant
# 84                           Sushi Restaurant
# 85                        Rental Car Location
# 86                                Karaoke Bar
# 87                                Gas Station
# 88                                       Food
# 89                               Home Service
# 90                               Dance Studio
# 91                               Intersection
# 92                           Asian Restaurant
# 93                                   Creperie
# 94                                 Nail Salon
# 95                             Shop & Service
# 96                            Automotive Shop
# 97                     Furniture / Home Store
# 98                                Auto Garage
# 99                                Pop-Up Shop
# 100                               Beer Garden
# 101                              Climbing Gym
# 102                          Cuban Restaurant
# 103                             Smoothie Shop
# 104                                   Brewery
# 105                         German Restaurant
# 106                                  Pie Shop
# 107                               Men's Store
# 108                                 Gun Range
# 109                                    Museum
# 110                               Event Space
# 111                          Stationery Store
# 112                          Ramen Restaurant
# 113           Southern / Soul Food Restaurant
# 114                                 Gastropub
# 115                         French Restaurant
# 116                                 Wine Shop
# 117                       Arts & Crafts Store
# 118                     Street Food Gathering
# 119                                     Plaza
# 120                                    Bridge
# 121                           Bubble Tea Shop
# 122                               Supermarket
# 123                                       Gym
# 124                                  Tea Room
# 125                              Concert Hall
# 126                   New American Restaurant
# 127                            Cosmetics Shop
# 128                               Gaming Cafe
# 129                     Vietnamese Restaurant
# 130                               Record Shop
# 131                       Sporting Goods Shop
# 132                             Indie Theater
# 133                 South American Restaurant
# 134                              Gourmet Shop
# 135                      Gym / Fitness Center
# 136                           Motorcycle Shop
# 137                            Shipping Store
# 138                 Middle Eastern Restaurant
# 139                          Storage Facility
# 140             Paper / Office Supplies Store
# 141                         Indian Restaurant
# 142                                   Theater
# 143                         Martial Arts Dojo
# 144                Construction & Landscaping
# 145                               Film Studio
# 146                              Cupcake Shop
# 147                            Lingerie Store
# 148                        Frozen Yogurt Shop
# 149                               Wings Joint
# 150                                Kids Store
# 151                           Supplement Shop
# 152                                      Bank
# 153                         Accessories Store
# 154                             Shopping Mall
# 155                          Insurance Office
# 156                              Dessert Shop
# 157                          Indoor Play Area
# 158                                     Trail
# 159                     Indonesian Restaurant
# 160                               Bus Station
# 161                   State / Provincial Park
# 162                        Athletics & Sports
# 163                               Flower Shop
# 164                                    Garden
# 165                               Fish Market
# 166                            Scenic Lookout
# 167                                      Cave
# 168                          Sculpture Garden
# 169                                 Speakeasy
# 170                        Photography Studio
# 171                                 Hotel Bar
# 172                               Golf Course
# 173                                  Gym Pool
# 174                                Hotel Pool
# 175                              Tennis Court
# 176                                     Field
# 177                                    Lawyer
# 178                      Arts & Entertainment
# 179                                      Road
# 180                         Other Repair Shop
# 181                        Dim Sum Restaurant
# 182                                Poke Place
# 183                       Dumpling Restaurant
# 184                               Salad Place
# 185                        Salon / Barbershop
# 186                          Doner Restaurant
# 187                             Women's Store
# 188                              Optical Shop
# 189                            Pilates Studio
# 190                                    Lounge
# 191                                Smoke Shop
# 192                                Bagel Shop
# 193                                    Buffet
# 194                          Tapas Restaurant
# 195                                Steakhouse
# 196                             Movie Theater
# 197                          Greek Restaurant
# 198                            Shopping Plaza
# 199                           Doctor's Office
# 200                      Kitchen Supply Store
# 201                            Chocolate Shop
# 202                               Cheese Shop
# 203                       Filipino Restaurant
# 204                        Falafel Restaurant
# 205                         Kosher Restaurant
# 206                                       ATM
# 207                          Recording Studio
# 208                               Flea Market
# 209                                     Track
# 210                      Brazilian Restaurant
# 211                           Bed & Breakfast
# 212                                   Dog Run
# 213                              Soccer Field
# 214  Residential Building (Apartment / Condo)
# 215                               Candy Store
# 216                                 Jazz Club
# 217                           Udon Restaurant
# 218                                  Building
# 219                                    Market
# 220                               Opera House
# 221                                    School
# 222                          Pedestrian Plaza
# 223                               Shoe Repair
# 224                               High School
# 225                 Cajun / Creole Restaurant
# 226                        Yoshoku Restaurant
# 227                             Train Station
# 228                                    Office
# 229                                   Library
# 230                        Miscellaneous Shop
# 231                                 Irish Pub
# 232                                 Multiplex
# 233                               Snack Place
# 234                               Comedy Club
# 235                                    Hostel
# 236                              Cycle Studio
# 237                                       Pub
# 238                        Donburi Restaurant
# 239                               Music Store
# 240                          Baseball Stadium
# 241                      Ethiopian Restaurant
# 242                            History Museum
# 243                          Business Service
# 244                         Food & Drink Shop
# 245                                   Exhibit
# 246                            Science Museum
# 247                        Light Rail Station
# 248                              Food Service
# 249                         Electronics Store
# 250                     General Entertainment
# 251                                 Roof Deck
# 252                                 Cafeteria
# 253                                  Beer Bar
# 254                      Outdoor Supply Store
# 255                            Medical Center
# 256                     Check Cashing Service
# 257                      Other Great Outdoors
# 258                       Monument / Landmark
# 259                      Taiwanese Restaurant
# 260                             Travel Lounge
# 261                                   Airport
# 262                        Child Care Service
# 263                                     Plane
# 264                               Summer Camp
# 265                     Outdoors & Recreation
# 266                   Scandinavian Restaurant
# 267                           Cultural Center
# 268                                Hookah Bar
# 269                                Food Court
# 270                                   Gay Bar
# 271                              Neighborhood
# 272                           Coworking Space
# 273                                Hobby Shop
# 274                                Theme Park
# 275                                Board Shop
# 276                           Laundry Service
# 277                         College Cafeteria
# 278                           College Theater
# 279                                  Bus Line
# 280                  Bike Rental / Bike Share
# 281                             Garden Center
# 282                       Indie Movie Theater
# 283                                  Bus Stop
# 284                                      Tree
# 285                             Auto Workshop
# 286                             Circus School
# 287                             Burrito Place
# 288                          Basketball Court
# 289                                Sports Bar
# 290                                 Disc Golf
# 291                                    Tunnel
# 292                        Tex-Mex Restaurant
# 293                                      Farm
# 294                            Soccer Stadium
# 295                    College Football Field
# 296                              Amphitheater
# 297                          Football Stadium
# 298                                  Aquarium
# 299                         Outdoor Sculpture
# 300                         College Bookstore
# 301                         College Classroom
# 302                              College Quad
# 303                 College Academic Building
# 304                                  Fountain
# 305                         Fish & Chips Shop
# 306                               Fabric Shop
# 307                              Costume Shop
# 308                               Bridal Shop
# 309                             Tattoo Parlor
# 310                               Pastry Shop
# 311                    Argentinian Restaurant
# 312                              Noodle House
# 313                              Antique Shop
# 314                                 Drugstore
# 315                                Whisky Bar
# 316                        Basketball Stadium
# 317                    Gluten-free Restaurant
# 318                                Food Stand
# 319                                  Mountain
# 320                                   Stables
# 321                Financial or Legal Service
# 322                        Spanish Restaurant
# 323                          Motorsports Shop
# 324                                Strip Club
# 325                   Comfort Food Restaurant
# 326                             Bowling Alley
# 327                           Organic Grocery
# 328                        Dongbei Restaurant
# 329              Theme Park Ride / Attraction
# 330                              Night Market
# 331                             Moving Target
# 332                     Entertainment Service
# 333                          Halal Restaurant
# 334                                    Casino
# 335                             Luggage Store
# 336                               Boat Rental
# 337                             Track Stadium
# 338                            Nightlife Spot
# 339                                  Cemetery
# 340                             Tour Provider
# 341                            Gymnastics Gym
# 342               Eastern European Restaurant
# 343                       Hawaiian Restaurant
# 344                                   Butcher
# 345                               Dry Cleaner
# 346                                     Beach
# 347                           Harbor / Marina
# 348                             Boat or Ferry
# 349                   North Indian Restaurant
# 350                                     River
# 351                               IT Services
# 352                            Medical School
# 353                      Herbs & Spices Store
# 354                              Chiropractor
# 355                           Photography Lab
# 356                                      Lake
# 357                              Skating Rink
# 358                                    Bistro
# 359                               Post Office
# 360                              Camera Store
# 361                                Print Shop
# 362                    College Residence Hall
# 363                          Fraternity House
# 364                      Himalayan Restaurant
# 365                                    Resort
# 366                                Street Art
# 367                        English Restaurant
# 368                                   Stadium
# 369                   Fruit & Vegetable Store
# 370                          Spiritual Center
# 371                               College Gym
# 372                           College Stadium
# 373                                Waterfront
# 374                                Toll Booth
# 375                       Empanada Restaurant
# 376                        African Restaurant
# 377                                Campground
# 378                       Moroccan Restaurant
# 379                                 Dive Shop
# 380                                Baby Store
# 381                                  Car Wash
# 382                       Government Building
# 383                                 Locksmith
# 384                                 Pool Hall
# 385                               Pet Service
# 386                                Vape Store
# 387                              Carpet Store
# 388                                 Reservoir
# 389                             Design Studio
# 390                        Burmese Restaurant
# 391                              Perfume Shop
# 392                        Russian Restaurant
# 393                             Tanning Salon
# 394                            Adult Boutique
# 395                                Astrologer
# 396                                  Tiki Bar
# 397                        Golf Driving Range
# 398                             Event Service
# 399                                    Forest
# 400                                 Rest Area
# 401                          Airport Terminal
# 402                       Leather Goods Store
# 403                                Watch Shop
# 404                     Australian Restaurant
# 405                                  Platform
# 406                                Public Art
# 407                                 Bike Shop
# 408                                 Laser Tag
# 409                            Mattress Store
# 410                                Soup Place
# 411                       Distribution Center
# 412                       Szechuan Restaurant
# 413                           Auto Dealership
# 414                        Persian Restaurant
# 415                         Jewish Restaurant
# 416                          Theme Restaurant
# 417                Tourist Information Center

# %% [markdown]
# **Define keywords for the general categories and categorize the venues based on the keywords**

# %%
# Define a list of keywords for each category
attractions = ["Gallery", "Historic", "Park", "Recreation", "Scenic", "Garden", "Museum", "Aquarium",
               "Beach", "Public Art", "Resort", "Exhibit", "Marina", "Lake", "Monument", "Landmark",
               "Mountain", "Arcade", "Cultural", "Fountain", "Tour", "Waterfront", "Massage", 
               "Performing", "club", "Pool", "Circus", "Skate", "Playground", "Yoga", "Spa",
               "Gun Range", "Gym", "Gaming", "Theater", "Golf", "Entertainment", "Lounge", 
               "Stadium", "Amphitheater", "Bowling", "Casino", "Nightlife", "Rink", "Dive",
               "Laser Tag", "Shopping"]

food_services = ["Restaurant", "Bar", "Coffee Shop", "BBQ", "Beer", "Breakfast", "Taco", "Sandwich", "Food", "Café",
              "Pizza", "Joint", "Donut", "Diner", "Ice Cream", "Creperie", "Smoothie", "Pie", "Gastropub", "Tea",
              "Cupcake", "Yogurt", "Dessert", "Salad", "Bagel", "Steak", "Chocolate", "Cheese", "Pub", "Snack",
              "Cafeteria", "Burrito", "Chips", "Pastry", "Noodle", "Bistro", "Soup" ]

medical = ["Doctor", "Pharmacy", "Drugstore", "Clinic", "Hospital", "Dispensary", "Medical Center" ]

transport = ["Airport", "Train", "Road", "Bus Stop", "Bus Station", "Rail", "Parking", "Car", "Garage", "Plane",
            "Bus Line", "Bike", "Boat"]
                 
for index, row in la_venues.iterrows():
    for keyword in attractions:
        if keyword in row["Venue Category"]:
            la_venues.loc[index, "General Category"] = "Attractions/Entertainments"
    for keyword in food_services:
        if keyword in row["Venue Category"]:
            la_venues.loc[index, "General Category"] = "Food Services"
    for keyword in medical:
        if keyword in row["Venue Category"]:
            la_venues.loc[index, "General Category"] = "Medical Services"
    for keyword in transport:
        if keyword in row["Venue Category"]:
            la_venues.loc[index, "General Category"] = "Transportation"

la_venues.fillna("Others", inplace=True)

la_venues.head()
# Out:
#        Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Angelino Heights                34.0703               -118.2548
# 1  Angelino Heights                34.0703               -118.2548
# 2  Angelino Heights                34.0703               -118.2548
# 3  Angelino Heights                34.0703               -118.2548
# 4  Angelino Heights                34.0703               -118.2548
#
#                  Venue  Venue Latitude  Venue Longitude  \
# 0      Halliwell Manor       34.069329      -118.254165
# 1             Guisados       34.070262      -118.250437
# 2     Eightfold Coffee       34.071245      -118.250698
# 3                Ototo       34.072659      -118.251740
# 4  Subliminal Projects       34.072290      -118.250737
#
#           Venue Category            General Category
# 0  Performing Arts Venue  Attractions/Entertainments
# 1             Taco Place               Food Services
# 2            Coffee Shop               Food Services
# 3               Sake Bar               Food Services
# 4            Art Gallery  Attractions/Entertainments

# %% [markdown]
# ### Create a profile for recommendation

# %%
profile = { "Attractions/Entertainments": 0.50, "Food Services": 0.15, "Medical Services": 0.15,
           "Transportation": 0.20, "Others": 0 }
profile = pd.Series(profile)
profile
# Out:
# Attractions/Entertainments    0.50
# Food Services                 0.15
# Medical Services              0.15
# Transportation                0.20
# Others                        0.00
# dtype: float64

# %% [markdown]
# **Create dummy variables for each General Category**

# %%
categories = pd.get_dummies(la_venues["General Category"])
categories.head()
# Out:
#    Attractions/Entertainments  Food Services  Medical Services  Others  \
# 0                           1              0                 0       0
# 1                           0              1                 0       0
# 2                           0              1                 0       0
# 3                           0              1                 0       0
# 4                           1              0                 0       0
#
#    Transportation
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %% [markdown]
# Add a **Neighborhood** column to the **categories** dataframe

# %%
current_columns = categories.columns.to_list()
categories["Neighborhood"] = la_venues["Neighborhood"]
categories = categories[["Neighborhood"] + current_columns]
categories.head()
# Out:
#        Neighborhood  Attractions/Entertainments  Food Services  \
# 0  Angelino Heights                           1              0
# 1  Angelino Heights                           0              1
# 2  Angelino Heights                           0              1
# 3  Angelino Heights                           0              1
# 4  Angelino Heights                           1              0
#
#    Medical Services  Others  Transportation
# 0                 0       0               0
# 1                 0       0               0
# 2                 0       0               0
# 3                 0       0               0
# 4                 0       0               0

# %% [markdown]
# **Group the categories dataframe by Neighborhood**

# %%
categories = categories.groupby("Neighborhood").sum()
categories.head()
# Out:
#                    Attractions/Entertainments  Food Services  \
# Neighborhood
# Angeles Mesa                                4             16
# Angelino Heights                           20             51
# Angelus Vista                               7             61
# Arleta                                      1              4
# Arlington Heights                           3             23
#
#                    Medical Services  Others  Transportation
# Neighborhood
# Angeles Mesa                      3      13               0
# Angelino Heights                  1      21               1
# Angelus Vista                     2      22               2
# Arleta                            0       5               0
# Arlington Heights                 2      11               3

# %% [markdown]
# ### Create a recommendation table

# %% [markdown]
# **Next, we take the weighted average of each neighborhood based on the defined profile and then make recommendations**

# %%
recommendation_df = ((categories * profile).sum(axis=1)) / (profile.sum())
recommendation_df.head()
# Out:
# Neighborhood
# Angeles Mesa          4.85
# Angelino Heights     18.00
# Angelus Vista        13.35
# Arleta                1.10
# Arlington Heights     5.85
# dtype: float64

# %% [markdown]
# **Let's see the top 5 recommended neighborhoods**

# %%
recommendation_df.sort_values(ascending=False, inplace=True)
recommendation_df.head()
# Out:
# Neighborhood
# Carthay            21.85
# Miracle Mile       21.00
# Little Ethiopia    20.45
# Whitley Heights    19.85
# Exposition Park    19.50
# dtype: float64

# %% [markdown]
# ### Get a summary of the top 10 recommended neighborhoods

# %%
recommendations = categories.loc[recommendation_df.head(10).index, :].reset_index()
recommendations.index = range(1, 11)
recommendations
# Out:
#         Neighborhood  Attractions/Entertainments  Food Services  \
# 1            Carthay                          30             43
# 2       Miracle Mile                          28             44
# 3    Little Ethiopia                          27             44
# 4    Whitley Heights                          28             39
# 5    Exposition Park                          24             49
# 6     Yucca Corridor                          22             53
# 7       Park La Brea                          25             42
# 8      Cahuenga Pass                          19             57
# 9   Angelino Heights                          20             51
# 10         Chinatown                          16             62
#
#     Medical Services  Others  Transportation
# 1                  0      25               2
# 2                  0      26               2
# 3                  1      27               1
# 4                  0      33               0
# 5                  1      16               0
# 6                  0      25               0
# 7                  0      33               0
# 8                  1      23               0
# 9                  1      21               1
# 10                 0      19               3

# %% [markdown]
# Now that we have made recommendations for the best locations to establish a tourism-based hotel in Los Angeles, further investigations/analysis of other factors based on the preference of the prospective owner can then be made to narrow down the number of potential locations.

# %% [markdown]
# ### Thanks for viewing this notebook.
# ### Author: OLALEKE Moshood A.
